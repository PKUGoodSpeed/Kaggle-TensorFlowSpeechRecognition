# %% [markdown]
# #### In this file, I just wanna play a little with the audio files

# %%
import os
from os.path import isdir, join
from pathlib import Path
import pandas as pd

import numpy as np
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
import librosa

# %%
from sklearn.decomposition import PCA

#Visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
import librosa.display

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import pandas as pd
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
test_path = '/Users/goodspeed/Documents/Kaggles/Kaggle-TensorFlowSpeechRecognition/pkugoodspeed/data/test/audio'
fname = 'clip_800326f00.wav'
rate, samples = wavfile.read(test_path + '/' + fname)
print(rate)
print(samples)
plt.plot(samples)
# Out:
# 16000
# [-3 -6 -2 ..., -7 -9 -8]

# %%
r2, s2 = wavfile.read(test_path + '/' + 'clip_bf7787f42.wav')
print (r2, s2)
# Out:
# 16000 [  8  16  22 ..., -42 -38 -27]

# %%
print(len(samples))
# Out:
# 16000

# %%
import IPython.display as ipd

# %%
ipd.Audio(samples, rate=rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
freq, times, spec = signal.spectrogram(samples, fs=rate, window='hann', nperseg=int(20*rate/1000), 
                                       noverlap=int(0*rate/1000))
print(freq)
print(times)
print(spec)
print(np.shape(spec))
spec = np.log(spec + 1.E-10)
# Out:
# [    0.    50.   100.   150.   200.   250.   300.   350.   400.   450.
#    500.   550.   600.   650.   700.   750.   800.   850.   900.   950.
#   1000.  1050.  1100.  1150.  1200.  1250.  1300.  1350.  1400.  1450.
#   1500.  1550.  1600.  1650.  1700.  1750.  1800.  1850.  1900.  1950.
#   2000.  2050.  2100.  2150.  2200.  2250.  2300.  2350.  2400.  2450.
#   2500.  2550.  2600.  2650.  2700.  2750.  2800.  2850.  2900.  2950.
#   3000.  3050.  3100.  3150.  3200.  3250.  3300.  3350.  3400.  3450.
#   3500.  3550.  3600.  3650.  3700.  3750.  3800.  3850.  3900.  3950.
#   4000.  4050.  4100.  4150.  4200.  4250.  4300.  4350.  4400.  4450.
#   4500.  4550.  4600.  4650.  4700.  4750.  4800.  4850.  4900.  4950.
#   5000.  5050.  5100.  5150.  5200.  5250.  5300.  5350.  5400.  5450.
#   5500.  5550.  5600.  5650.  5700.  5750.  5800.  5850.  5900.  5950.
#   6000.  6050.  6100.  6150.  6200.  6250.  6300.  6350.  6400.  6450.
# ...

# %%
print(np.max(spec))
print(np.min(spec))
# Out:
# 13.1532
# -18.5232
