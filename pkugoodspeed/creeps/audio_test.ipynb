# %% [markdown]
# #### In this file, I just wanna play a little with the audio files

# %%
import os
from os.path import isdir, join
import pandas as pd

import numpy as np
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile

# %%
from sklearn.decomposition import PCA

#Visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import pandas as pd
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
test_path = '../data/train/audio/silence'
fname = 'doing_the_dishes.wav'
rate, samples = wavfile.read(test_path + '/' + fname)
print(rate)
print(samples)
plt.plot(samples)
print len(samples)
# Out:
# 16000
# [   0    0    0 ..., -194 -133  -83]
# 1522930

# %%
r2, s2 = wavfile.read(test_path + '/' + 'clip_bf7787f42.wav')
print (r2, s2)
# Out:
# (16000, array([  8,  16,  22, ..., -42, -38, -27], dtype=int16))

# %%
print(len(samples))
# Out:
# 16000

# %%
import IPython.display as ipd

# %%
ipd.Audio(samples, rate=rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
freq, times, spec = signal.spectrogram(samples, fs=rate, window=('kaiser',10), nperseg=int(25*rate/1000), 
                                       noverlap=int(15*rate/1000))
print(freq)
print(times)
print(spec)
print(np.shape(spec))
spec = np.log(spec + 1.E-10)
# Out:
# [    0.    40.    80.   120.   160.   200.   240.   280.   320.   360.
#    400.   440.   480.   520.   560.   600.   640.   680.   720.   760.
#    800.   840.   880.   920.   960.  1000.  1040.  1080.  1120.  1160.
#   1200.  1240.  1280.  1320.  1360.  1400.  1440.  1480.  1520.  1560.
#   1600.  1640.  1680.  1720.  1760.  1800.  1840.  1880.  1920.  1960.
#   2000.  2040.  2080.  2120.  2160.  2200.  2240.  2280.  2320.  2360.
#   2400.  2440.  2480.  2520.  2560.  2600.  2640.  2680.  2720.  2760.
#   2800.  2840.  2880.  2920.  2960.  3000.  3040.  3080.  3120.  3160.
#   3200.  3240.  3280.  3320.  3360.  3400.  3440.  3480.  3520.  3560.
#   3600.  3640.  3680.  3720.  3760.  3800.  3840.  3880.  3920.  3960.
#   4000.  4040.  4080.  4120.  4160.  4200.  4240.  4280.  4320.  4360.
#   4400.  4440.  4480.  4520.  4560.  4600.  4640.  4680.  4720.  4760.
#   4800.  4840.  4880.  4920.  4960.  5000.  5040.  5080.  5120.  5160.
#   5200.  5240.  5280.  5320.  5360.  5400.  5440.  5480.  5520.  5560.
#   5600.  5640.  5680.  5720.  5760.  5800.  5840.  5880.  5920.  5960.
#   6000.  6040.  6080.  6120.  6160.  6200.  6240.  6280.  6320.  6360.
#   6400.  6440.  6480.  6520.  6560.  6600.  6640.  6680.  6720.  6760.
#   6800.  6840.  6880.  6920.  6960.  7000.  7040.  7080.  7120.  7160.
#   7200.  7240.  7280.  7320.  7360.  7400.  7440.  7480.  7520.  7560.
#   7600.  7640.  7680.  7720.  7760.  7800.  7840.  7880.  7920.  7960.
#   8000.]
# [ 0.0125  0.0225  0.0325  0.0425  0.0525  0.0625  0.0725  0.0825  0.0925
#   0.1025  0.1125  0.1225  0.1325  0.1425  0.1525  0.1625  0.1725  0.1825
#   0.1925  0.2025  0.2125  0.2225  0.2325  0.2425  0.2525  0.2625  0.2725
#   0.2825  0.2925  0.3025  0.3125  0.3225  0.3325  0.3425  0.3525  0.3625
#   0.3725  0.3825  0.3925  0.4025  0.4125  0.4225  0.4325  0.4425  0.4525
#   0.4625  0.4725  0.4825  0.4925  0.5025  0.5125  0.5225  0.5325  0.5425
#   0.5525  0.5625  0.5725  0.5825  0.5925  0.6025  0.6125  0.6225  0.6325
#   0.6425  0.6525  0.6625  0.6725  0.6825  0.6925  0.7025  0.7125  0.7225
#   0.7325  0.7425  0.7525  0.7625  0.7725  0.7825  0.7925  0.8025  0.8125
#   0.8225  0.8325  0.8425  0.8525  0.8625  0.8725  0.8825  0.8925  0.9025
#   0.9125  0.9225  0.9325  0.9425  0.9525  0.9625  0.9725  0.9825]
# [[  2.40458292e-03   1.37018673e-02   1.63864213e-04 ...,   1.33918165e-05
#     2.28084084e-02   4.87960987e-02]
#  [  7.69078434e-02   1.06451018e-02   1.46554941e-02 ...,   7.99313374e-03
#     5.50009124e-02   3.63238268e-02]
#  [  2.21630201e-01   9.31167006e-02   2.59078860e-01 ...,   5.77859655e-02
#     1.44466281e-01   2.88159829e-02]
#  ...,
#  [  2.04784428e-05   1.01402557e-05   7.11458997e-05 ...,   3.41711238e-05
#     2.61636869e-05   6.33720265e-05]
#  [  3.02754506e-05   3.92356305e-05   6.32206356e-05 ...,   3.99897144e-05
#     1.87318910e-05   8.95475969e-05]
#  [  9.37982895e-06   2.70031705e-05   1.05158015e-05 ...,   4.70331397e-05
#     6.09461267e-06   7.01563549e-05]]
# (201, 98)

# %%
print(np.max(spec))
print(np.min(spec))
# Out:
# 13.0917
# -23.0066

# %%
168/8
# Out:
# 21

# %%
176/8
# Out:
# 22
